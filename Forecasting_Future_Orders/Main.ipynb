# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Without_Duplicated.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df.set_index('date').asfreq('D')
# mean_value=df['total_orders'].mean()
# #df['date'] = pd.to_datetime(df['date'])
# #df = df.set_index('date').asfreq('D')
# #df.set_index('date').asfreq=('D')
#df_comp = df.fillna(value=mean_value)

# %%
# Out:
# Empty DataFrame
# Columns: [total_orders]
# Index: []

# %%
df
# Out:
#             total_orders
# date
# 2021-08-10         455.0
# 2021-08-11         553.0
# 2021-08-12         569.0
# 2021-08-13         426.0
# 2021-08-14         536.0
# ...                  ...
# 2021-11-04        1876.0
# 2021-11-05        1442.0
# 2021-11-06        2032.0
# 2021-11-07        2117.0
# 2021-11-08        2063.0
#
# [91 rows x 1 columns]

# %%
df[df['total_orders'].isnull()].index.tolist()
# Out:
# [Timestamp('2021-08-18 00:00:00', freq='D')]

# %%
mean_value=df['total_orders'].mean()
df=df.fillna(value=mean_value)

# %%
df[df['total_orders'].isnull()].index.tolist()
# Out:
# []

# %%
df.plot(figsize=(17,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.rcParams['figure.figsize'] = [15, 8]
results = seasonal_decompose(df['total_orders'])
results.plot();

# %%
len(df)
# Out:
# 91
